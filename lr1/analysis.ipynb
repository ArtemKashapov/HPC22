# %%
import matplotlib.pyplot as plt

# %%
# Полученные результаты
sz_arr = [100, 200, 400, 800, 1000, 1500, 2000]
cpu_arr = [0.43225998878479005, 0.4594260692596436, 0.43705339431762696, 0.6184375762939454, 0.77061767578125, 1.4970709323883056, 3.739762783050537]
gpu_arr = [0.006201457977294922, 0.012402677536010742, 0.026805925369262695, 0.0822944164276123, 0.1359025001525879, 0.4498856544494629, 2.2791616439819338]
simple_arr = [0.00850987434387207, 0.036625909805297854, 0.1804809093475342, 0.9324944496154786, 1.6750042915344239, 5.979011201858521, 15.05576777458191]

# %%
from cProfile import label


plt.figure(figsize=(16, 8))
plt.plot(sz_arr, simple_arr, lw=4, label='Single CPU')
plt.plot(sz_arr, cpu_arr, lw=4, label='MultiCPU')
plt.plot(sz_arr, gpu_arr, lw=4, label='GPU')
plt.grid()
plt.legend()
plt.xlim([sz_arr[0], sz_arr[-1]])
plt.xlabel('Размерность матриц')
plt.ylabel('Скорость выполнения, сек')
plt.show()
